# %%
# Load dependencies
import tensorflow as tf
from tensorflow import keras
from keras.models import load_model
from os.path import exists
from os import listdir

# %%
# Loads best model from directory, if it exists
if exists("./models/checkpoints/asl"):
    checkpoints = listdir("./models/checkpoints/asl")
    if len(checkpoints) > 0:
        model = load_model("./models/checkpoints/asl/" + checkpoints[len(checkpoints)-1])
# Out:
# 2022-04-19 09:25:02.282712: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-04-19 09:25:02.282820: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Metal device set to: Apple M1
#
# systemMemory: 8.00 GB
# maxCacheSize: 2.67 GB

# %%
# Create data generator for test data
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255
)

# %%
# Load test data from directory
test_generator = test_datagen.flow_from_directory(
    "./asl_alphabet_test/",
    target_size=(224,224),
    classes=['asl_alphabet_test'],
    batch_size=32,
    shuffle=True
)
# Out:
# Found 28 images belonging to 1 classes.

# %%
# Generate predictions
predictions = model.predict(test_generator)
# Out:
# 2022-04-19 09:25:04.546345: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-04-19 09:25:04.630167: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.

# %%
# Predictions are in form of a probability distribution
print(predictions)
# Out:
# [[0.03416327 0.03443502 0.03422153 0.03416815 0.03428147 0.03462133
#   0.03425498 0.03441586 0.03409204 0.03464727 0.03490771 0.03373968
#   0.03477161 0.03448406 0.03469356 0.03424999 0.03490652 0.03499691
#   0.03393702 0.03444664 0.03464162 0.03402571 0.03487597 0.03485049
#   0.03474974 0.03420838 0.03460842 0.03507388 0.03453125]
#  [0.03416327 0.03443502 0.03422153 0.03416815 0.03428147 0.03462133
#   0.03425498 0.03441586 0.03409204 0.03464727 0.03490771 0.03373968
#   0.03477161 0.03448406 0.03469356 0.03424999 0.03490652 0.03499691
#   0.03393702 0.03444664 0.03464162 0.03402571 0.03487597 0.03485049
#   0.03474974 0.03420838 0.03460842 0.03507388 0.03453125]
#  [0.03416327 0.03443502 0.03422153 0.03416815 0.03428147 0.03462133
#   0.03425498 0.03441586 0.03409204 0.03464727 0.03490771 0.03373968
#   0.03477161 0.03448406 0.03469356 0.03424999 0.03490652 0.03499691
#   0.03393702 0.03444664 0.03464162 0.03402571 0.03487597 0.03485049
# ...
